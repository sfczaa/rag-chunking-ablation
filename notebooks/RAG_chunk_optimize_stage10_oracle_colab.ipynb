# %% [markdown]
# # Stage 10 oracle - ceiling for cut placement
#
# Scores 18 chunkings per document with the question available, which bounds what any
# in-window cut placement can gain.
# Details: `docs/stage10_rl_chunking.md`, "Oracle ceiling". Needs the Stage 2 weights
# and the Stage 8 NQ-train cache.

# %% [markdown]
# ## Setup

# %%
# project folder on Drive
PROJECT_DIR = '/content/drive/MyDrive/RAG chunk optimize'

from google.colab import drive
drive.mount('/content/drive')

import os, sys
if not os.path.isfile(os.path.join(PROJECT_DIR, 'config.py')):
    raise RuntimeError(f'no config.py under {PROJECT_DIR!r} - fix PROJECT_DIR above.')

os.environ['RAG_DATA_ROOT'] = PROJECT_DIR + '/artifacts'
sys.path.insert(0, PROJECT_DIR)
os.chdir(PROJECT_DIR)

import config as C
C.ensure_dirs()
print('project:', PROJECT_DIR)
print(C.summary())

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Smoke check
#
# A 40-document slice, and three documents recomputed through the RL reward path.
# Outputs use a `smoke_` prefix.

# %%
# !python scripts/25_placement_oracle.py --smoke

# %% [markdown]
# ## The measurement
#
# 400 documents, K = 16, checkpointed after every document. `--fresh` starts over.

# %%
# !python scripts/25_placement_oracle.py

# %% [markdown]
# ## Review

# %%
import os, pathlib
from IPython.display import Image, Markdown, display

latest = pathlib.Path(os.environ['RAG_DATA_ROOT']) / 'results' / 'latest'
summary = latest / 'stage10_oracle_summary.md'
if summary.exists():
    display(Markdown(summary.read_text(encoding='utf-8')))
    display(Image(str(latest / 'stage10_oracle_best_of_k.png')))
else:
    print('no oracle summary yet - the measurement has not finished.')

# %% [markdown]
# ## Verdicts
#
# `CLOSED`, `INCONCLUSIVE`, `SIZE-CONFOUNDED` and `HEADROOM` are defined in
# `docs/stage10_rl_chunking.md`.
